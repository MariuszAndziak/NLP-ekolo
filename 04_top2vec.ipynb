# %%
# pip install top2vec

# pip install top2vec[sentence_encoders]
# pip install top2vec[sentence_transformers]
# pip install top2vec[indexing]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from top2vec import Top2Vec
import top2vec

# %%
pd.set_option('max_colwidth', 400)

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', 'SelectableGroups dict interface')

# %%
df_all = pd.read_hdf('outputs/budzety_clean.hd5', key='df_all')
df_all = df_all.reset_index()
del df_all['index']

# %%
df_all
# Out:
#         rok  miasto  \
# 0      2020  GDYNIA
# 1      2020  GDYNIA
# 2      2020  GDYNIA
# 3      2020  GDYNIA
# 4      2020  GDYNIA
# ...     ...     ...
# 23025  2020  KRAKÓW
# 23026  2020  KRAKÓW
# 23027  2020  KRAKÓW
# 23028  2020  KRAKÓW
# 23029  2020  KRAKÓW
#
#                                                                                                                                                                            nazwa  \
# 0                                                                                                                                                                 Projektistatus
# 1      Doposażenie parku pomiędzy Estakadą Kwiatkowskiego a wieżowcami przy ul. Dantyszka 2,4,8 w siłownię zewnętrzną i elementy małej architektury - pergole, bujane ławki itp.
# 2                                                                                          Cykliczne warsztaty dla seniorów z dzielnicy Obłuże rozwijające pamięć i koncentrację
# 3                                                                                                                               Ogród Sąsiedzki przy Dzikim Sadzie, ul. Źródlana
# 4                                                   Montaż słupów oświetleniowych na chodniku przy ul. Niskiej na odcinku pomiędzy ul. Bohaterów Getta Warszawskiego i Hodowlaną
# ...                                                                                                                                                                          ...
# 23025                                                                                                                                                  Zielony skwer na Zabtociu
# 23026                                                                                                                                    Znani Biatopradniczanie dla Mieszkanców
# 23027                                                                                                                 ZRÓBMY SKWER PRZY FABRYCZNEJ! Edukacja i kultura w zieleni
# 23028                                                                                                                                                          Zróbmy sobie Park
# 23029                                                                                                                                                           ZUMBA DLA DZIECI
#
#        WSZYSTKO  \
# 0             0
# 1             3
# 2             0
# 3             3
# 4             0
# ...         ...
# 23025         1
# 23026         0
# 23027         1
# 23028         1
# 23029         0
#
#                                                                                                                                                                  tokens  \
# 0                                                                                                                                                      [projektistatus]
# 1      [doposażenie, park, pomiędzy, estakada, kwiatkowskiego, wieżowiec, ul, dantyszka, siłownia, zewnętrzny, element, mały, architektura, pergola, bujać, ławka, itp]
# 2                                                                                      [cykliczny, warsztat, senior, dzielnica, obłuże, rozwijać, pamięć, koncentracja]
# 3                                                                                                                         [ogród, sąsiedzki, dziki, sadź, ul, źródlana]
# 4                                                       [montaż, słup, oświetleniowy, chodnik, ul, niski, odcinek, pomiędzy, ul, bohater, getto, warszawski, hodowlany]
# ...                                                                                                                                                                 ...
# 23025                                                                                                                                        [zielony, skwer, zabtociu]
# 23026                                                                                                                                              [znany, mieszkanców]
# 23027                                                                                                             [zrobić, skwer, fabryczny, edukacja, kultura, zieleń]
# 23028                                                                                                                                                    [zrobić, park]
# 23029                                                                                                                                                  [zumba, dziecko]
#
#        zbiornik  sadzić  estetyczny  lęgowy  ekologia  ...  deszczowy  \
# 0         False   False       False   False     False  ...      False
# 1         False   False       False   False     False  ...      False
# 2         False   False       False   False     False  ...      False
# 3         False   False       False   False     False  ...      False
# 4         False   False       False   False     False  ...      False
# ...         ...     ...         ...     ...       ...  ...        ...
# 23025     False   False       False   False     False  ...      False
# 23026     False   False       False   False     False  ...      False
# 23027     False   False       False   False     False  ...      False
# 23028     False   False       False   False     False  ...      False
# 23029     False   False       False   False     False  ...      False
#
#        kwitnąć  ogrodowy  pielęgnacja   smog  zieleniec  \
# 0        False     False        False  False      False
# 1        False     False        False  False      False
# 2        False     False        False  False      False
# 3        False     False        False  False      False
# 4        False     False        False  False      False
# ...        ...       ...          ...    ...        ...
# 23025    False     False        False  False      False
# 23026    False     False        False  False      False
# 23027    False     False        False  False      False
# 23028    False     False        False  False      False
# 23029    False     False        False  False      False
#
#                                                                                                                                                 names  \
# 0                                                                                                                                      projektistatus
# 1      doposażenie park pomiędzy estakada kwiatkowskiego wieżowiec ul dantyszka siłownia zewnętrzny element mały architektura pergola bujać ławka itp
# 2                                                                             cykliczny warsztat senior dzielnica obłuże rozwijać pamięć koncentracja
# 3                                                                                                              ogród sąsiedzki dziki sadź ul źródlana
# 4                                                   montaż słup oświetleniowy chodnik ul niski odcinek pomiędzy ul bohater getto warszawski hodowlany
# ...                                                                                                                                               ...
# 23025                                                                                                                          zielony skwer zabtociu
# 23026                                                                                                                               znany mieszkanców
# 23027                                                                                                  zrobić skwer fabryczny edukacja kultura zieleń
# 23028                                                                                                                                     zrobić park
# 23029                                                                                                                                   zumba dziecko
#
#        szkola  ulica  oswietlenie
# 0       False  False        False
# 1       False   True        False
# 2       False  False        False
# 3       False   True        False
# 4       False   True         True
# ...       ...    ...          ...
# 23025   False  False        False
# 23026   False  False        False
# 23027   False  False        False
# 23028   False  False        False
# 23029   False  False        False
#
# [23030 rows x 61 columns]

# %%
docs = list(df_all.loc[:, 'names'].values)
docs = [str(elem) for elem in docs]

# %%
# !!!!!! WAŻNE !!!!!!
#
# Jeżeli masz w  folderze models plik:
# 'main_top2vec_topic.model' to nie uruchamiaj
# tej komórki 

model = Top2Vec(docs, embedding_model='distiluse-base-multilingual-cased')
model.save('models/main_top2vec_topic.model')

# %%
# Ładowanie wcześniej wytrenowanego modelu
model = Top2Vec.load('models/main_top2vec_topic.model')

# %%
# Łącznie mamy tyle tematów
model.get_num_topics()
# Out:
# 252

# %%
# Ograniczamy liczbę tematów
N_TOPICS = 20
model.hierarchical_topic_reduction(N_TOPICS)
# Out:
# [[8,
#   86,
#   141,
#   158,
#   173,
#   185,
#   13,
#   97,
#   81,
#   109,
#   144,
#   101,
#   198,
#   18,
#   93,
#   161,
#   176,
#   31,
#   179,
#   190,
#   143,
#   239,
#   42,
#   186,
#   174,
#   114,
#   37,
#   76,
#   219,
#   49,
#   224,
#   77,
#   50,
#   91,
#   108,
#   216,
#   74,
#   149,
#   222,
#   181,
#   162,
#   100,
#   90,
#   80,
#   229,
#   51,
#   182,
#   157,
#   163,
#   193,
#   55,
#   107,
#   232,
#   137,
#   217,
#   129,
#   215,
#   233,
#   192,
#   199,
#   191,
#   153,
#   172,
#   248,
#   236,
#   3],
#  [205,
#   11,
#   175,
#   207,
#   56,
#   131,
#   113,
#   85,
#   146,
#   135,
#   147,
#   188,
#   202,
#   197,
#   212,
#   246,
#   1],
#  [103,
#   99,
#   94,
#   250,
#   139,
#   34,
#   231,
#   156,
#   177,
#   88,
#   25,
#   127,
#   44,
#   62,
#   71,
#   115,
#   184,
#   6],
#  [168,
#   96,
#   73,
#   225,
#   214,
#   148,
#   57,
#   136,
#   27,
#   145,
#   33,
#   124,
#   133,
#   102,
#   68,
#   195,
#   240,
#   70],
#  [201, 118, 171, 12, 194, 237, 204, 112, 243, 111, 119, 166, 211, 235, 241, 4],
#  [116,
#   122,
#   223,
#   227,
#   242,
#   247,
#   22,
#   208,
#   251,
#   132,
#   60,
#   43,
#   84,
#   83,
#   128,
#   134,
#   159,
#   206,
#   209,
#   230,
#   28],
#  [244, 121, 0],
#  [54, 228, 245, 196, 126, 164, 249, 5],
#  [138, 238, 40, 45, 67, 61, 69, 180, 221, 17],
#  [26, 21, 75, 72, 65, 226, 130, 14],
#  [154, 41, 39, 178, 66, 64, 150, 2],
#  [151, 30, 167, 203, 125, 59, 46, 63, 38],
#  [106, 105, 189, 23, 187, 52, 234, 10],
#  [142, 53, 210, 220, 16],
#  [123, 117, 213, 20, 152, 58, 82, 79, 183, 169],
#  [104, 7],
#  [110, 92, 29, 87, 9],
#  [95, 89, 170, 48, 47, 35],
#  [36, 120, 32],
#  [160, 24, 155, 165, 200, 19, 140, 78, 98, 218, 15]]

# %%
# Wyciągamy numery tematów, słowa należące do tematów oraz wyniki podobieństwa słów
topic_words, word_scores, topic_nums = model.get_topics(reduced=True)

# %%
# Podgląd słów stanowiących temat 10
topic_words[10]
# Out:
# array(['zielony', 'ekologiczny', 'trawnik', 'otoczenie', 'zielen',
#        'drzewo', 'kolorowy', 'ogrod', 'krzew', 'solankowy', 'sasiedzki',
#        'ogolnodostepny', 'kieszonkowy', 'dzielnicowy', 'eko',
#        'ogrodzenie', 'okolica', 'cmentarz', 'zewnetrzny', 'wesoły',
#        'katowicach', 'kwiat', 'terenowy', 'plenerowy', 'nawierzchnia',
#        'dzielnica', 'duzy', 'smog', 'asfaltowy', 'bieznia', 'srodmiescie',
#        'paweł', 'osiedlowy', 'szczecina', 'spacerowy', 'kosciuszki',
#        'parka', 'rejon', 'planszowy', 'ptasi', 'parkowy', 'mieszkaniec',
#        'skatepark', 'łodzki', 'osiedle', 'mieszkancow', 'słoneczny',
#        'park', 'pomiedzy', 'strefa'], dtype='<U14')

# %%
# Najbardziej podobne słowa do wskazanego
words, word_scores = model.similar_words(keywords=["wodny"], keywords_neg=[], num_words=20)

for word, score in zip(words, word_scores):
    print(f"{word} {score}")
# Out:
# woda 0.8887221721700655
# fontanna 0.8736314465529534
# zbiornik 0.7702461908420606
# łodzki 0.726416237238739
# wesoły 0.701764093091277
# zielen 0.7013671054207301
# zatoka 0.7010200297948638
# wokoł 0.6913450191992665
# wiata 0.6888200803103339
# stawa 0.6872777005299338
# zewnetrzny 0.6840146142579648
# plenerowy 0.6770060497793041
# postojowy 0.6711096612902037
# zajecia 0.669015934066059
# smog 0.6663478350115257
# letni 0.6660540663355172
# łodz 0.6651854679219588
# ogrod 0.6622361993340345
# ławka 0.6605649185746785
# paweł 0.6589068382255714

# %%
# Wyszukaj dokumenty najbardziej związane z danym słowem
documents, document_scores, document_ids = model.search_documents_by_keywords(keywords=["siłownia"], num_docs=20)
for doc, score, doc_id in zip(documents, document_scores, document_ids):
    print(f"Document: {doc_id}, Score: {score}")
    print("-----------")
    print(doc)
    print("-----------")
    print()
# Out:
# Document: 21652, Score: 0.9282288650291024
# -----------
# siłownia prusie
# -----------
#
# Document: 17359, Score: 0.9028826841243502
# -----------
# siłownia napowietrzny
# -----------
#
# Document: 6393, Score: 0.8969578456041496
# -----------
# siłownia zewnętrzny
# -----------
#
# Document: 16705, Score: 0.8969578456041496
# -----------
# siłownia zewnętrzny
# -----------
#
# Document: 9401, Score: 0.8969578456041496
# -----------
# siłownia zewnętrzny
# -----------
#
# Document: 16430, Score: 0.8956741431653565
# -----------
# siłownia łubinką
# -----------
#
# Document: 18665, Score: 0.8922036582521022
# -----------
# siłownia plenerowy
# -----------
#
# Document: 20275, Score: 0.8922036582521022
# -----------
# siłownia plenerowy
# -----------
#
# Document: 9349, Score: 0.8922036582521022
# -----------
# siłownia plenerowy
# -----------
#
# Document: 21502, Score: 0.8922036582521022
# -----------
# siłownia plenerowy
# -----------
#
# Document: 12156, Score: 0.8528759785513514
# -----------
# siłownia zewnętrzny sp
# -----------
#
# Document: 15090, Score: 0.8528759785513514
# -----------
# siłownia zewnętrzny sp
# -----------
#
# Document: 10525, Score: 0.8453088944441225
# -----------
# siłownia plener
# -----------
#
# Document: 20284, Score: 0.8395497916692831
# -----------
# fitness młocinach
# -----------
#
# Document: 18900, Score: 0.838770669463356
# -----------
# siłownia plenerowy sp
# -----------
#
# Document: 13072, Score: 0.838770669463356
# -----------
# siłownia plenerowy sp
# -----------
#
# Document: 16239, Score: 0.8290670555825638
# -----------
# siłownia oświecenie
# -----------
#
# Document: 10783, Score: 0.8276199589972193
# -----------
# siłownia lmk bulwar
# -----------
#
# Document: 13337, Score: 0.8158914812134491
# -----------
# sala gimnastyczny sp
# -----------
#
# Document: 11889, Score: 0.8158914812134491
# -----------
# sala gimnastyczny sp
# -----------

# %%
df_all['nazwa'].iloc[21652]
# Out:
# 'Siłownia w Prusie'

# %%
df_all['nazwa'].iloc[11889]
# Out:
# 'Sala gimnastyczna w SP 3.'

# %%
# Pokaż 4 dokumenty (o największym prawdopodobieństwie) należące do tematu nr 18
SELECTED_TOPIC = 18
documents, document_scores, document_nums = model.search_documents_by_topic(topic_num=SELECTED_TOPIC, num_docs=4, reduced=True)
    
result_df = df_all.loc[document_nums]
result_df["document_scores"] = document_scores
print(f'Temat: {SELECTED_TOPIC}')
print(*topic_words[18])
result_df[['nazwa', 'names', 'document_scores']]
# Out:
# Temat: 18
# ulica uliczny street chodnik asfaltowy drogowy trasa walking spacerowy dojazdowy przejazd srodmiescie jezdny skrzyzowanie trawnik kierunek jazda sasiedzki kieszonkowy dzielnicowy pieszo ogrod biegowy miasteczko zewnetrzny plaza nawierzchnia pumptrack ogolnodostepny skatepark skarpa zatoka przejscie ławeczka poprzez plenerowy dzielnica zabytkowy mieszkaniec okolica mieszkancow kanał terenowy rowerzysta krzew miejski przystankowy drogi pieszy miasto
#                                                nazwa  \
# 13732    Chodnik między ulicami Owsianą i Grochową.
# 20174  Wysepki dla pieszych na ulicy Szczęśliwickiej
# 22346               Piesi na chodnik na ulicy Krysta
# 15994                    Chodnik przy ulicy Łokietka
#
#                                     names  document_scores
# 13732      chodnik ulica owsiany grochowy         0.938815
# 20174  wysepka pieszy ulica szczęśliwicki         0.934723
# 22346         pieszy chodnik ulica krysta         0.926460
# 15994              chodnik ulica łokietek         0.922255

# %%
# Indeksy wszystkich dokumentów
indeksy = df_all.index.tolist()

# %%
# Buduj tematy dla dokumentów
documents_topics = model.get_documents_topics(indeksy, reduced=True)

# %%
# documents_topics składa się z 4 list:
# 0 - Numer tematu dla poszczególnego dokumentu
# 1 - Semantyczne podobieństwo dokumentu do tematu (odl. cosinusowa wektora dokumentu
#  i tematu)
# 2 - Top 50 słów danego tematu
# 3 - Odległość cosinusowa tematów z każdym z top 50 słów
# Out:
# 4

# %%
# Zapisanie tematów do DataFrame'a
df_all['topics'] = documents_topics[0]

# %%
df_all['topics_desc'] = pd.DataFrame(documents_topics[2]).agg(' '.join, axis=1).agg(lambda x: x.split())

# %%
df_all.to_hdf('outputs/budzety_clean_topics_top2vec.h5', key='df_all')
