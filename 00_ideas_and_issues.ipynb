# %%
import pandas as pd
df = pd.read_hdf('outputs/budzety_clean_topics_bert.h5', key='df')

# %% [markdown]
# # Pomysły co robić dalej, problemy, wyzwania, itp...

# %% [markdown]
# ***

# %% [markdown]
# ## Wybór odpowiedniej metody reprezentacji tematów

# %% [markdown]
# 1. BERTopic
# 2. LDA
# 3. Top2Vec
# 4. inna...

# %% [markdown]
# ***

# %% [markdown]
# ## Różna ilość tematów

# %% [markdown]
# Modyfikujemy zmienną `N_TOPICS` i patrzymy jakie tematy otrzymujemy.
# Proponuję wybierać większą liczbę tematów niż proponowane 20.

# %% [markdown]
# ***

# %% [markdown]
# ## Grupowanie tematów

# %% [markdown]
# Utworzyć cechę `topics_groups` i poprzypisywać do niej poszczególne tematy. Tzn. grupa zielona to tematy 12, 5, 4 i 6, grupa czerwona to tematy 17, 8, 13, 1, 14 itp.
# Grupy mogą mieć jakieś nazwy (podejście subiektywne) np. zieleń, transport, sport...
# Grupowanie tematów nie musi być robione w odniesieniu do kolorów. Można wejść na wyższy poziom klastrowania hierachicznego i np. podzielić je względem konkrentego poziomu
# Np. pierwszy podział klastrowania to podział na grupy, do którtych należą tematy 15 12 5 4 6 17 8 13 1 14 (pierwsza grupa) i pozostałe tematy (jako druga grupa). Więc tworzymy tylko 2 grupy.

# %%
df[['nazwa', 'topics']]
# Out:
#                                                    nazwa  topics
# 0                                         Projektistatus      -1
# 1      Doposażenie parku pomiędzy Estakadą Kwiatkowsk...       3
# 2      Cykliczne warsztaty dla seniorów z dzielnicy O...       1
# 3       Ogród Sąsiedzki przy Dzikim Sadzie, ul. Źródlana       8
# 4      Montaż słupów oświetleniowych na chodniku przy...      -1
# ...                                                  ...     ...
# 23025                          Zielony skwer na Zabtociu      13
# 23026            Znani Biatopradniczanie dla Mieszkanców       2
# 23027  ZRÓBMY SKWER PRZY FABRYCZNEJ! Edukacja i kultu...      11
# 23028                                  Zróbmy sobie Park      15
# 23029                                   ZUMBA DLA DZIECI       3
#
# [23030 rows x 2 columns]

# %% [markdown]
# ![title](images/topics.png)

# %% [markdown]
# ***

# %% [markdown]
# ## Rozbicie algorytmu Bertopic

# %% [markdown]
# Rozbijamy Bertopic na UMAP i HDBSCAN i próbujemy różnych parametrów tych dwóch algorytmów.

# %%
# UMAP - zmniejszenie ilości wymiarów
umap_model = umap.UMAP(n_neighbors=15,
                       n_components=10,
                       min_dist=0.0,
                       metric='cosine',
                       low_memory=False)

# HDBSAN - klasteryzacja dokumentów
hdbscan_model = hdbscan.HDBSCAN(min_cluster_size=10,
                                min_samples=1,
                                metric='euclidean',
                                cluster_selection_method='eom',
                                prediction_data=True)

# %%
# Bertopic
model = BERTopic(top_n_words=20,
                       n_gram_range=(1,2), 
                       calculate_probabilities=True,
                       umap_model= umap_model,
                       hdbscan_model=hdbscan_model,
                       similarity_threshold_merging=0.5,
                       verbose=True,
                       language='polish')

topics, probs = model.fit_transform(docs)
# lub 
# topics, probs = model.fit_transform(docs, embeddings)
# jeżeli bierzemy pod uwagę embeddingi (patrz punkt poniżej)

# %% [markdown]
# ***

# %% [markdown]
# ## Użycie różnych embeddingów

# %% [markdown]
# Tokeny mogą być różnie reprezentowane (embedding)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(min_df=5)
embeddings = vectorizer.fit_transform(docs)
topics, probs = model.fit_transform(docs, embeddings)

# lub

from sentence_transformers import SentenceTransformer

sentence_model = SentenceTransformer("distiluse-base-multilingual-cased")
embeddings = sentence_model.encode(docs, show_progress_bar=False)
topics, probs = model.fit_transform(docs, embeddings)

# %% [markdown]
# Istnieje całe mnóstwo reprezentacji wektorowych, każda z nich może mieć dodatkowo swoje własne parametry

# %% [markdown]
# ***

# %% [markdown]
# ## Badanie trendów zmian

# %%
def most_common_topics(city: str, year: str, top: int = 3) -> pd.Series:
  result = df[(df['miasto'] == city) & (df['rok'] == year)]['topics'].value_counts()[1:top+1]
  return result

# %% [markdown]
# Wybieramy miasto i patrzymy jakie były najpopularniejsze tematy na przestrzen lat.
# (Domyślnie 3 tematy z pominięciem szumu)

# %%
most_common_topics('GDYNIA', '2018')
# Out:
# 0     9
# 14    8
# 8     5
# Name: topics, dtype: int64

# %%
most_common_topics('GDYNIA', '2018/19')
# Out:
# Series([], Name: topics, dtype: int64)

# %%
most_common_topics('GDYNIA', '2019')
# Out:
# 0    44
# 3    17
# 1    11
# Name: topics, dtype: int64

# %%
most_common_topics('GDYNIA', '2020')
# Out:
# 0    39
# 1    24
# 3    18
# Name: topics, dtype: int64

# %% [markdown]
# Widzimy, że w Gdyni najpopularniejsze były tematy `0 8 14`, potem `0 1 3` i rok później również `0 1 3`. To już jest podstawą do utworzenia pewnej historii.

# %% [markdown]
# Możemy nie patrzeć na zmiany tematów na przestrzeni lat, ale na zmiany w grupach tematów na przestrzeni lat.

# %% [markdown]
# Jeżeli mamy już informację o zmianie tematów na przestrzeni lat dla danego miasta to możemy sprawdzić z czego ona wynika.
# Czy na tą zmianę miało wpływ to, że:
# * miasta o podobnej liczbie ludności do wybranego wykazywały podobne trendy zmian na przestrzeni lat
# * miasta o podobnej powierzchni do wybranego wyjazywały podobne trendy zmian na przestrzeni lat
# * miasta sąsiadujące z wybranym miastem i ich najpopularniejsze tematy wpłynęły na zmianę w tematach wybranego miasta
# na przestrzeni lat
# * czy miasta o podobnym budżecie przeliczonym na 100 tys. mieszkańców jak nasze wybrane miasto "interesowały" się podobnym tematami

# %% [markdown]
# ***

# %% [markdown]
# ## Problemy do rozpracowania ::: Sprawdzenie poprawności klasyfikacji tematów

# %% [markdown]
# Nie wszystkie tematy zostały dobrze sklasyfikowane

# %%
pd.set_option('max_colwidth', 400)
pd.DataFrame(df[['rok', 'miasto', 'topics', 'topics_desc', 'nazwa', 'names']].iloc[18589]).T
# Out:
#         rok    miasto topics  \
# 18589  2018  WARSZAWA     12
#
#                                                                                  topics_desc  \
# 18589  [pies, psi, ursynów, pszczoła, komar, ursynowie, owad, nietoperz, zwierzę, wiewiórka]
#
#                        nazwa               names
# 18589  Scrabble na Ursynowie  scrabble ursynowie

# %% [markdown]
# Np. zauważyłem, że dla Ursynowa bardzo dużo wpada do kategorii `zwierzęcej` (temat nr 12)

# %%
df[df['nazwa'].str.contains('Ursyn')][['topics', 'topics_desc', 'nazwa']]
# Out:
#        topics  \
# 17953      12
# 17967       7
# 17977      -1
# 18022      12
# 18069      14
# ...       ...
# 22108      12
# 22112      12
# 22114      12
# 22115      -1
# 22119      -1
#
#                                                                                               topics_desc  \
# 17953               [pies, psi, ursynów, pszczoła, komar, ursynowie, owad, nietoperz, zwierzę, wiewiórka]
# 17967     [chodnik, warszawa, warszawski, warszawo, park, polski, budynek, miejsce, sąsiedzki, poznański]
# 17977       [chodnik, park, ulica, budowa, warsztat, koncert, miejsce, dzielnica, modernizacja, muzyczny]
# 18022               [pies, psi, ursynów, pszczoła, komar, ursynowie, owad, nietoperz, zwierzę, wiewiórka]
# 18069  [cmentarz, kościół, pomnik, rewitalizacja, rzeźba, wieża, chodnik, ulica, obserwatorium, widokowy]
# ...                                                                                                   ...
# 22108               [pies, psi, ursynów, pszczoła, komar, ursynowie, owad, nietoperz, zwierzę, wiewiórka]
# 22112               [pies, psi, ursynów, pszczoła, komar, ursynowie, owad, nietoperz, zwierzę, wiewiórka]
# 22114               [pies, psi, ursynów, pszczoła, komar, ursynowie, owad, nietoperz, zwierzę, wiewiórka]
# 22115       [chodnik, park, ulica, budowa, warsztat, koncert, miejsce, dzielnica, modernizacja, muzyczny]
# 22119       [chodnik, park, ulica, budowa, warsztat, koncert, miejsce, dzielnica, modernizacja, muzyczny]
#
#                                                                                  nazwa
# 17953                       Doświetlenie przejść dla pieszych na Ursynowie Południowym
# 17967                                               Pij, Warszawo (Ursynów Południowy)
# 17977                                                               Ursynowskie Murale
# 18022                         Doświetlenie przejść dla pieszych na Ursynowie Północnym
# 18069                                 Ursynowskie rzeźby po 40-tu latach do renowacji
# ...                                                                                ...
# 22108                            Neon na budynku Dzielnicowego Ośrodka Kultury Ursynów
# 22112                                   Doświetlenie przejść dla pieszych na Ursynowie
# 22114  Bezpłatne zajęcia dla dzieci i młodzieży w Dzielnicowym Ośrodku Kultury Ursynów
# 22115                                                     Letnie koncerty na Ursynowie
# 22119            Piękne rośliny na ulicach Ursynowa, chroniące przed smogiem i hałasem
#
# [111 rows x 3 columns]

# %% [markdown]
# Chyba przyporządkowuje `Ursynów` jako `urson`

# %% [markdown]
# ![title](images/urson.png)
# źródło: https://pl.wikipedia.org/wiki/Urson_ameryka%C5%84ski

# %% [markdown]
# Podobnie wiele tematów z miasta Łódź jest błędnie przypisywanych do kategorii `morsko-rzecznej`

# %%
df[df['nazwa'].str.contains('Łodzi')][['topics', 'topics_desc', 'nazwa']]
# Out:
#        topics  \
# 11504      15
# 11961      -1
# 12011      15
# 12057      15
# 12167      -1
# ...       ...
# 14974      15
# 14981      -1
# 14984      15
# 14985      15
# 14999       6
#
#                                                                                          topics_desc  \
# 11504            [łódź, plaża, plażowy, łódzki, morski, kajakowy, łódka, kajak, łodzianin, pomorski]
# 11961  [chodnik, park, ulica, budowa, warsztat, koncert, miejsce, dzielnica, modernizacja, muzyczny]
# 12011            [łódź, plaża, plażowy, łódzki, morski, kajakowy, łódka, kajak, łodzianin, pomorski]
# 12057            [łódź, plaża, plażowy, łódzki, morski, kajakowy, łódka, kajak, łodzianin, pomorski]
# 12167  [chodnik, park, ulica, budowa, warsztat, koncert, miejsce, dzielnica, modernizacja, muzyczny]
# ...                                                                                              ...
# 14974            [łódź, plaża, plażowy, łódzki, morski, kajakowy, łódka, kajak, łodzianin, pomorski]
# 14981  [chodnik, park, ulica, budowa, warsztat, koncert, miejsce, dzielnica, modernizacja, muzyczny]
# 14984            [łódź, plaża, plażowy, łódzki, morski, kajakowy, łódka, kajak, łodzianin, pomorski]
# 14985            [łódź, plaża, plażowy, łódzki, morski, kajakowy, łódka, kajak, łodzianin, pomorski]
# 14999   [senior, zdrowie, kobieta, zdrowy, seniora, kuchnia, kulinarny, szpital, medyczny, catering]
#
#                                                                                                                     nazwa
# 11504                                                                      Mistrzostwa Miasta Gorzowa w Smoczych Łodziach
# 11961                                                     PLAŻA W ARTURÓWKU- miejscem wypoczynku i rekreacji dla Łodzian.
# 12011  Kino plenerowe - letnie w Arturówku - miejscem wypoczynku i rekreacji dla Łodzian. Bliżej kultury na łonie natury.
# 12057                 Drzwi do przyszłości - kolorowe i bezpieczne wejście do sal zabaw i nauki dla najmłodszych Łodzian.
# 12167               Budowa boiska wielofunkcyjnego sportowego o sztucznej nawierzchni przy SP 113 w Łodzi, ul. Unicka 6.
# ...                                                                                                                   ...
# 14974                           Bezpieczna 4-stka monitoring wizyjny wokół szkoły podstawowej nr 4 w Łodzi, ul. Milionowa
# 14981                                                       Przywróćmy blask infrastrukturze sportowej w XXIX LO w Łodzi.
# 14984                                       Remont szatni w budynku Szkoły Podstawowej nr 64 w Łodzi, ul. Wróblewskiego 6
# 14985                                                         Sala językowa dla uczniów Szkoły Podstawowej nr 64 w Łodzi.
# 14999                                                     Centralnym Szpitalu Klinicznym Uniwersytetu Medycznego w Łodzi.
#
# [187 rows x 3 columns]
